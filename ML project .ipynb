# %%
import tkinter as tk
from tkinter import *
from tkinter import filedialog
from tkinter.filedialog import askopenfilename
from sklearn.metrics import plot_confusion_matrix
from sklearn.feature_selection import RFE
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.svm import SVC
from sklearn import svm
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

myframe = Tk()
myframe.title("ML project")
myframe.geometry("800x600")
my_font1=('times', 18, 'bold')
    

def linear_regression():
    new=Toplevel(myframe)
    new.geometry("800x750")
    new.title("liner regression")
    def data():
        global df
        global check
        filename = askopenfilename(initialdir='C:\Files',title = "Select file") 
        check = StringVar()
        check = "Dataset is uploaded"
        file = open(filename, 'r')
        t_upload.insert(END, check)
        df = pd.read_csv(filename)
    def train_data():
    
        testSize=float(splitEntry.get())
    
        try:
            testSize=float(splitEntry.get())

        except ValueError:
            print('Test Size value is not a float')
    
        X = df.iloc[:, :-1]
        y = df.iloc[:, -1]
    
        global X_train, X_test, y_train, y_test 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testSize, random_state=42)
    
        global model
        model=LinearRegression()
        model.fit(X_train,y_train)
        error_message = " train is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def test_data():
        if not len(t_train.get("1.0", 'end-1c')):
            error_message = "Train the Model First!"
            t_train.delete("1.0", "end")
            t_train.insert(END, error_message)
            return
        global pred
        pred = model.predict(X_test)
        error_message = " test is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def res():
        train_data()
        test_data()
        pop=Toplevel()
        pop.geometry("400x400")
        pop.title("Results")
        lbl=Label(pop,text="RMSE: "+ str(metrics.mean_squared_error(pred,y_test)))
        lbl.pack()

        pop.mainloop()


    LabelFrame1=LabelFrame(new,text="Loading data")
    LabelFrame1.pack(fill="both",ipadx=5,ipady=5)
    l1=Label(LabelFrame1, text='Select Data File')
    l1.grid(row=0, column=0)
    e1=Entry(LabelFrame1,text='')
    e1.grid(row=0, column=1)

    Button(LabelFrame1,text='open', command=data).grid(row=0, column=2)


    paramFrame=LabelFrame(new,text="Parameters")
    paramFrame.pack(fill="both")


    Button(paramFrame, text='Train', command=train_data).grid(row=3,column=2)
    Button(paramFrame, text='Test',command=test_data).grid(row=3,column=3)

    splitLabel=Label(paramFrame, text='Test size:')
    splitLabel.grid(row=3,column=0,padx=10,pady=10)

    splitEntry=Entry(paramFrame)
    splitEntry.grid(row=3, column=1,padx=10,pady=10)

    Button(new, text='Result', command=res).place(x=230,y=230)
    Button(new, text='Close', command=new.destroy).place(x=300,y=230)


    t_upload = Text(new, width=24, height=1)
    t_train = Text(new, width=20, height=1)

    t_upload.place(x=280, y=18)
    t_train.place(x=380, y=80)


def open_win():
    new1=Toplevel(myframe)
    new1.geometry("800x750")
    new1.title("rfe")
    
    def data():
        global filename
        filename = askopenfilename(initialdir=r'C:\Files',title = "Select file")
        e1.insert(0, filename)
        e1.config(text=filename)

        global file
        file = pd.read_csv(filename)
        for i in file.columns:
            box1.insert(END,i)
    def model():
        x= file.iloc[:, :-1] 
        y= file.iloc[:,1]

        model=svm.SVR(kernel = "linear")
        rfe = RFE(model , n_features_to_select = 5)
        rfe = rfe.fit(x,y)
        filter = rfe.support_
        ranking = rfe.ranking_
   
        print(filter)
        print(ranking)
        data = x[x.columns[filter]]
        data["outcome"] = y
        data.to_csv("newdata.csv" , index=False)

    l1=Label(new1, text='Select Data File')
    l1.grid(row=0, column=0)
    e1 = Entry(new1,text='')
    e1.grid(row=0, column=1)
    Button(new1,text='open', command=data,activeforeground="white",activebackground="black").grid(row=0, column=2)
    box1 = Listbox(new1,selectmode='multiple')
    box1.place(x=330,y=50)
    Button(new1,text="Recursive feature elimination",command=model,activeforeground="white",activebackground="black").place(x=305,y=250)
    Button(new1, text="next>>",font="system",command=newwin).place(x=360,y=340)    

mybutton=Button(myframe, text="Classification", bg="#e3f2fd",font="Helvatica 15 bold",command=open_win).place(x=330,y=140)
mybutton=Button(myframe, text="Linear Regression",bg="#e3f2fd",font="Helvatica 15 bold",command=linear_regression).place(x=310,y=240)


def newwin():
    new2=Toplevel(myframe)
    new2.geometry("800x600")
    new2.title("Algorithms")
   
    Label(new2, text="Algorithm",font="Helvatica 15 bold").place(x=350,y=75)

    Button(new2,text='K-Neighbors Classifier',command=KNN,activebackground="black",activeforeground="white").place(x=330,y=180)
    Button(new2,text='SVM Classifier',command=SVM,activebackground="black",activeforeground="white").place(x=350,y=280)
    Button(new2,text='DecisionTree Classifier',command=DecCls,activebackground="black",activeforeground="white").place(x=330,y=230)

def SVM():
    new3=Toplevel(myframe)
    new3.geometry("600x300")
    new3.title("svm Classifier GUI")
    def data():
        global df
        global check
        filename = askopenfilename(initialdir='C:\Files',title = "Select file") 
        check = StringVar()
        check = "Dataset is uploaded"
        file = open(filename, 'r')
        t_upload.insert(END, check)
        df = pd.read_csv(filename)
    def train_data():
    
        testSize=float(splitEntry.get())
    
        try:
            testSize=float(splitEntry.get())
        except ValueError:
            print('Test Size value is not a float')
    
        X = df.iloc[:, :-1]
        y = df.iloc[:, -1]

        global X_train, X_test, y_train, y_test 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testSize, random_state=42)
        if attribute_selection.get()=="linear":
            global clf
            clf=svm.SVC(kernel=attribute_selection.get())
        else:
            clf = svm.SVC(kernel=attribute_selection.get())
        clf = clf.fit(X_train, y_train)
        error_message = " train is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def test_data():
        if not len(t_train.get("1.0", 'end-1c')):
            error_message = "Train the Model First!"
            t_train.delete("1.0", "end")
            t_train.insert(END, error_message)
            return
        global pred
        pred = clf.predict(X_test)
        error_message = " test is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def res():
        train_data()
        test_data()
        pop=Toplevel()
        pop.geometry("400x400")
        pop.title("Results")
        lbl=Label(pop,text="Accuracy: "+ str(metrics.accuracy_score(y_test,pred)))
        lbl.pack()
        lbl1=Label(pop,text="Precision: "+ str(metrics.precision_score(y_test, pred)))
        lbl1.pack()
        lbl2=Label(pop,text="Recall: "+ str(metrics.recall_score(y_test, pred)))
        lbl2.pack()
        lbl6=Label(pop,text="F1 score: "+ str(metrics.f1_score(y_test,pred)))
        lbl6.pack()
        lbl7=Label(pop,text="Confusion_matrix "+ str(metrics.confusion_matrix(y_test,pred)))
        lbl7.pack()
        pop.mainloop()


    LabelFrame1=LabelFrame(new3,text="Loading data")
    LabelFrame1.pack(fill="both",ipadx=5,ipady=5)
    l1=Label(LabelFrame1, text='Select Data File')
    l1.grid(row=0, column=0)
    e1=Entry(LabelFrame1,text='')
    e1.grid(row=0, column=1)

    Button(LabelFrame1,text='open', command=data).grid(row=0, column=2)


    paramFrame=LabelFrame(new3,text="Parameters")
    paramFrame.pack(fill="both")


    kerneLabel=Label(paramFrame, text='Kernel Func:')
    kerneLabel.grid(row=1,column=0,pady=10,padx=10)

    OPTIONS = [
    "Select model",
    "linear",
    "rbf"
    ]

    attribute_selection = StringVar()
    attribute_selection.set(OPTIONS[0])

    kernelFunc=OptionMenu(paramFrame, attribute_selection, *OPTIONS)
    kernelFunc.grid(row=1,column=1,pady=10)

    
    Button(paramFrame, text='Train', command=train_data).grid(row=3,column=2)
    Button(paramFrame, text='Test',command=test_data).grid(row=3,column=3)

    splitLabel=Label(paramFrame, text='Test size:')
    splitLabel.grid(row=3,column=0,padx=10,pady=10)

    splitEntry=Entry(paramFrame)
    splitEntry.grid(row=3, column=1,padx=10,pady=10)

    Button(new3, text='Result', command=res).place(x=230,y=230)
    Button(new3, text='Close', command=new3.destroy).place(x=300,y=230)


    t_upload = Text(new3, width=24, height=1)
    t_train = Text(new3, width=20, height=1)
    t_upload.place(x=280, y=18)
    t_train.place(x=380, y=80)


def KNN():
    new4=Toplevel(myframe)
    new4.geometry("800x750")
    new4.title("K-Neighbors Classifier")
    def data():
        global df
        global check
        filename = askopenfilename(initialdir='C:\Files',title = "Select file") 
        check = StringVar()
        check = "Dataset is uploaded"
        file = open(filename, 'r')
        t_upload.insert(END, check)
        df = pd.read_csv(filename)
    def train_data():
    
        testSize=float(splitEntry.get())
    
        try:
            testSize=float(splitEntry.get())

        except ValueError:
            print('Test Size value is not a float')
    
        X = df.iloc[:, :-1]
        y = df.iloc[:, -1]

        global X_train, X_test, y_train, y_test 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testSize, random_state=42)
    
        global model
        model = KNeighborsClassifier(n_neighbors=7)
        model= model.fit(X_train, y_train)
        error_message = " train is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def test_data():
        if not len(t_train.get("1.0", 'end-1c')):
            error_message = "Train the Model First!"
            t_train.delete("1.0", "end")
            t_train.insert(END, error_message)
            return
        global pred
        pred = model.predict(X_test)
        error_message = " test is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def res():
        train_data()
        test_data()
        pop=Toplevel()
        pop.geometry("400x400")
        pop.title("Results")
        lbl=Label(pop,text="Accuracy: "+ str(metrics.accuracy_score(y_test,pred)))
        lbl.pack()
        lbl1=Label(pop,text="Precision: "+ str(metrics.precision_score(y_test, pred)))
        lbl1.pack()
        lbl2=Label(pop,text="Recall: "+ str(metrics.recall_score(y_test, pred)))
        lbl2.pack()
        lbl6=Label(pop,text="F1 score: "+ str(metrics.f1_score(y_test,pred)))
        lbl6.pack()
        lbl7=Label(pop,text="Confusion_matrix "+ str(metrics.confusion_matrix(y_test,pred)))
        lbl7.pack()
        pop.mainloop()


    LabelFrame1=LabelFrame(new4,text="Loading data")
    LabelFrame1.pack(fill="both",ipadx=5,ipady=5)
    l1=Label(LabelFrame1, text='Select Data File')
    l1.grid(row=0, column=0)
    e1=Entry(LabelFrame1,text='')
    e1.grid(row=0, column=1)

    Button(LabelFrame1,text='open', command=data).grid(row=0, column=2)


    paramFrame=LabelFrame(new4,text="Parameters")
    paramFrame.pack(fill="both")


    Button(paramFrame, text='Train', command=train_data).grid(row=3,column=2)
    Button(paramFrame, text='Test',command=test_data).grid(row=3,column=3)

    splitLabel=Label(paramFrame, text='Test size:')
    splitLabel.grid(row=3,column=0,padx=10,pady=10)
 
    splitEntry=Entry(paramFrame)
    splitEntry.grid(row=3, column=1,padx=10,pady=10)

    Button(new4, text='Result', command=res).place(x=230,y=230)
    Button(new4, text='Close', command=new4.destroy).place(x=300,y=230)


    t_upload = Text(new4, width=24, height=1)
    t_train = Text(new4, width=20, height=1)

    t_upload.place(x=280, y=18)
    t_train.place(x=380, y=80)

def DecCls():
    new5=Toplevel(myframe)
    new5.geometry("600x300")
    new5.title("DT Classifier GUI")
    
    def data():
        global df
        global check
        filename = askopenfilename(initialdir='C:\Files',title = "Select file") 
        check = StringVar()
        check = "Dataset is uploaded"
        file = open(filename, 'r')
        t_upload.insert(END, check)
        df = pd.read_csv(filename)
    def train_data():
    
        testSize=float(splitEntry.get())
    
        try:
            testSize=float(splitEntry.get())

        except ValueError:
            print('Test Size value is not a float')
    
        X = df.iloc[:, :-1]
        y = df.iloc[:, -1]
 
        global X_train, X_test, y_train, y_test 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testSize, random_state=42)
        if attribute_selection.get()=="gini":
            global clf
            clf=DecisionTreeClassifier(max_depth=3)
        else:
            clf=DecisionTreeClassifier()
        clf = clf.fit(X_train, y_train)
        error_message = " train is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def test_data():
        if not len(t_train.get("1.0", 'end-1c')):
            error_message = "Train the Model First!"
            t_train.delete("1.0", "end")
            t_train.insert(END, error_message)
            return
        global pred
        pred = clf.predict(X_test)
        error_message = " test is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def res():
        train_data()
        test_data()
        pop=Toplevel()
        pop.geometry("400x400")
        pop.title("Results")
        lbl=Label(pop,text="Accuracy: "+ str(metrics.accuracy_score(y_test,pred)))
        lbl.pack()
        lbl1=Label(pop,text="Precision: "+ str(metrics.precision_score(y_test, pred)))
        lbl1.pack()
        lbl2=Label(pop,text="Recall: "+ str(metrics.recall_score(y_test, pred)))
        lbl2.pack()
        lbl6=Label(pop,text="F1 score: "+ str(metrics.f1_score(y_test,pred)))
        lbl6.pack()
        lbl7=Label(pop,text="Confusion_matrix "+ str(metrics.confusion_matrix(y_test,pred)))
        lbl7.pack()
        plt.figure(figsize=(12,12))
        tree.plot_tree(clf, fontsize=6)
        plt.savefig('tree_high_dpi' , dpi=100)
        plt.show()
        pop.mainloop()


    LabelFrame1=LabelFrame(new5,text="Loading data")
    LabelFrame1.pack(fill="both",ipadx=5,ipady=5)
    l1=Label(LabelFrame1, text='Select Data File')
    l1.grid(row=0, column=0)
    e1=Entry(LabelFrame1,text='')
    e1.grid(row=0, column=1)
 
    Button(LabelFrame1,text='open', command=data).grid(row=0, column=2)


    paramFrame=LabelFrame(new5,text="Parameters")
    paramFrame.pack(fill="both")



    kerneLabel=Label(paramFrame, text='Kernel Func:')
    kerneLabel.grid(row=1,column=1,pady=10,padx=10)

    OPTIONS = [
    "Select model",
    "gini"
    ]

    attribute_selection = StringVar()
    attribute_selection.set(OPTIONS[0])

    kernelFunc=OptionMenu(paramFrame, attribute_selection, *OPTIONS)
    kernelFunc.grid(row=1,column=2,pady=10)

    Button(paramFrame, text='Train', command=train_data).grid(row=2,column=2)
    Button(paramFrame, text='Test',command=test_data).grid(row=2,column=3)

    splitLabel=Label(paramFrame, text='Test size:')
    splitLabel.grid(row=2,column=0,padx=10,pady=10)

    splitEntry=Entry(paramFrame)
    splitEntry.grid(row=2, column=1,padx=10,pady=10)

    Button(new5, text='Result', command=res).place(x=230,y=230)
    Button(new5, text='Close', command=new5.destroy).place(x=300,y=230)


    t_upload = Text(new5, width=24, height=1)
    t_train = Text(new5, width=20, height=1)

    t_upload.place(x=280, y=18)
    t_train.place(x=380, y=130)

myframe.mainloop()
